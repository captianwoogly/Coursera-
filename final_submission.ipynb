# %% [markdown]
# # Final Submission using Jupyter Notebook

# %% [markdown]
# **Varun Soni**

# %% [markdown]
# I am a 20 year old computer engineering student with interest in data science and web development.

# %% [markdown]
# *Data Science Langauges*
# * **Python**
# * **R**
# * **SQL**

# %% [markdown]
# **Data Science Libraries**
# * **TensorFlow**
# * **PyTorch**
# * **Scikit-learn**
# * **Pandas**
# * **Numpy**

# %% [markdown]
# | Name  |
# |-------|
# | Apache Spark |
# | Jupyter Notebook |

# %% [markdown]
# **Some common Arithmetic Operators are**
# * (+)
# * (-)
# * (/)
# * (*)

# %%
a=5
b=10
c=a*b
d=a+b
print(c,d)
# Out:
# 50 15

# %% [markdown]
# **Minutes to Hours**

# %%
minutes=120
hours=minutes/60
print(hours)
# Out:
# 2.0

# %% [markdown]
# **Objectives**
# * Learn Python or R
# * Build Projects
# * Get a job 🙌

# %% [markdown]
# *Author* : **Varun Soni**
